# 39.981400663066864 98.60309386682462
# -16.47941912571278 150.68858947210776
# 73.88578509850609 30.512129240892165
# -5.5505576566439885 -50.207702045920485
# 42.640459101995816 46.038091052469525
# 4.65362827484455 -39.506006622468306
# 29.902632658430576 20.29265723587426
# 61.9270371077489 157.32641603941732
# 0.9276010907912138 2.9507077012222
# 2.2286002636303124 37.391078400385055
# -13.674589262304607 155.72924090630931
# -19.928099583230235 54.47326339512631
# 49.564613559420565 -111.61968168587624
# 41.57324918899636 145.09698055411144
# -0.1584930380756049 75.75277171124068
# 56.96869965321733 75.95124406365937
# -14.488988328122446 16.749043081320167
# 39.16053088687775 105.16348815659325
# 42.28278751197416 136.02043252065909
# 49.85929216500301 -57.59715868268822
# -11.839413908608662 -74.86029636586831
# 23.17987093210725 -60.321575211856114
# 5.152626527792819 -70.20203554109483
# -9.339474872534453 106.93054745439707
# 21.29442688746977 90.4474953830919
# 13.88918426019191 -84.9132711843941
# 45.7713715001546 -75.94548727221918
# 5.075309748686536 -18.44461817583084
# -53.81555231652337 157.90094969251726
# 71.03606480730218 -143.14821919159186
# 26.076270907178483 -11.673208485780492
# 19.231308189404217 107.61920632086208

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import requests, json 

temp_list = []
humidity_list = []
pressure_list = []
wind_list = []
cloud_list = []
citylistclean = []
latlistclean =[]
lonlistclean =[]

for index in range(len(cities)):
    #print(lats_api[index],lngs_api[index])
    lat=lats_api[index]
    lon=lngs_api[index]
    
    # Enter your API key here 
    api_key = "a78acb322d4ec8950fb803b541264af4"

    # base_url variable to store url 
    base_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"


    # get method of requests module 
    # return response object 
    response = requests.get(base_url) 

    # json method of response object  
    # convert json format data into 
    # python format data 
    x = response.json() 

    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 

        # store the value of "main" 
        # key in variable y 
        y = x["main"] 

        # store the value corresponding 
        # to the "temp" key of y 
        current_temperature = y["temp"] 

        # store the value corresponding 
        # to the "pressure" key of y 
        current_pressure = y["pressure"] 

        # store the value corresponding 
        # to the "humidity" key of y 
        current_humidity = y["humidity"] 
        current_wind = x["wind"]["speed"]
        current_cloud = x["clouds"]["all"]
        
        # store the value of "weather" 
        # key in variable z 
        z = x["weather"] 

        # store the value corresponding  
        # to the "description" key at  
        # the 0th index of z 
        weather_description = z[0]["description"] 

        # print following values 
        print(index,cities[index])
        print(" Temperature (in kelvin unit) = " +
                        str(current_temperature) + 
              "\n atmospheric pressure (in hPa unit) = " +
                        str(current_pressure) +
              "\n humidity (in percentage) = " +
                        str(current_humidity) +
              "\n description = " +
                        str(weather_description)) 

        temp_list.append(current_temperature) 
        humidity_list.append(current_humidity) 
        pressure_list.append(current_pressure) 
        wind_list.append(current_wind) 
        cloud_list.append(current_cloud)
        citylistclean.append(cities[index])
        latlistclean.append(lat)
        lonlistclean.append(lon)
    else: 
        print(" City Not Found ")
# Out:
# 0 illoqqortoormiut
#  Temperature (in kelvin unit) = 274.27
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 91
#  description = broken clouds
# 1 ushuaia
#  Temperature (in kelvin unit) = 248.8
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 90
#  description = scattered clouds
# 2 bayir
#  Temperature (in kelvin unit) = 297.04
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 18
#  description = clear sky
# 3 bluff
#  Temperature (in kelvin unit) = 245.76
#  atmospheric pressure (in hPa unit) = 982
#  humidity (in percentage) = 79
#  description = clear sky
# 4 taolanaro
#  Temperature (in kelvin unit) = 219.66
#  atmospheric pressure (in hPa unit) = 1058
#  humidity (in percentage) = 39
#  description = overcast clouds
# 5 hobart
#  Temperature (in kelvin unit) = 280.86
#  atmospheric pressure (in hPa unit) = 1027
#  humidity (in percentage) = 77
#  description = clear sky
# 6 puerto ayora
#  Temperature (in kelvin unit) = 296.62
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 80
#  description = few clouds
# 7 bethel
#  Temperature (in kelvin unit) = 283.92
#  atmospheric pressure (in hPa unit) = 994
#  humidity (in percentage) = 95
#  description = overcast clouds
# 8 port alfred
#  Temperature (in kelvin unit) = 263.9
#  atmospheric pressure (in hPa unit) = 972
#  humidity (in percentage) = 95
#  description = overcast clouds
# 9 nazilli
#  Temperature (in kelvin unit) = 292.74
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 61
#  description = scattered clouds
# 10 nikolskoye
#  Temperature (in kelvin unit) = 279.54
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 94
#  description = broken clouds
# 11 camacha
#  Temperature (in kelvin unit) = 292.85
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 82
#  description = overcast clouds
# 12 mandalgovi
#  Temperature (in kelvin unit) = 283.33
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 76
#  description = light rain
# 13 vaini
#  Temperature (in kelvin unit) = 291.73
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 67
#  description = clear sky
# 14 never
#  Temperature (in kelvin unit) = 282.38
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 92
#  description = overcast clouds
# 15 idanre
#  Temperature (in kelvin unit) = 297.21
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 91
#  description = light rain
# 16 new norfolk
#  Temperature (in kelvin unit) = 221.52
#  atmospheric pressure (in hPa unit) = 1048
#  humidity (in percentage) = 42
#  description = broken clouds
# 17 meulaboh
#  Temperature (in kelvin unit) = 301.69
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 76
#  description = light rain
# 18 busselton
#  Temperature (in kelvin unit) = 285.09
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 71
#  description = overcast clouds
# 19 albany
#  Temperature (in kelvin unit) = 278.82
#  atmospheric pressure (in hPa unit) = 969
#  humidity (in percentage) = 93
#  description = overcast clouds
# 20 tasiilaq
#  Temperature (in kelvin unit) = 280.91
#  atmospheric pressure (in hPa unit) = 999
#  humidity (in percentage) = 93
#  description = overcast clouds
# 21 beringovskiy
#  Temperature (in kelvin unit) = 280.33
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 93
#  description = overcast clouds
# 22 tsaratanana
#  Temperature (in kelvin unit) = 297.6
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 57
#  description = clear sky
# 23 tsihombe
#  Temperature (in kelvin unit) = 293.3
#  atmospheric pressure (in hPa unit) = 1024
#  humidity (in percentage) = 68
#  description = clear sky
# 24 rurrenabaque
#  Temperature (in kelvin unit) = 299.85
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 60
#  description = broken clouds
# 25 ugoofaaru
#  Temperature (in kelvin unit) = 302.07
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 78
#  description = overcast clouds
# 26 gisborne
#  Temperature (in kelvin unit) = 285.98
#  atmospheric pressure (in hPa unit) = 1024
#  humidity (in percentage) = 65
#  description = broken clouds
# 27 ponta do sol
#  Temperature (in kelvin unit) = 298.27
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 78
#  description = broken clouds
# 28 daru
#  Temperature (in kelvin unit) = 298.47
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 82
#  description = clear sky
# 29 shizukuishi
#  Temperature (in kelvin unit) = 287.73
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 90
#  description = broken clouds
# 30 yellowknife
#  Temperature (in kelvin unit) = 273.77
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 94
#  description = scattered clouds
# 31 kieta
#  Temperature (in kelvin unit) = 302.38
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 70
#  description = broken clouds
# 32 ambilobe
#  Temperature (in kelvin unit) = 299.19
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 79
#  description = light rain
# 33 katsuura
#  Temperature (in kelvin unit) = 301.83
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 78
#  description = broken clouds
# 34 bicester
#  Temperature (in kelvin unit) = 298.47
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 47
#  description = clear sky
# 35 toliary
#  Temperature (in kelvin unit) = 295.08
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 77
#  description = clear sky
# 36 rikitea
#  Temperature (in kelvin unit) = 280.32
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 77
#  description = overcast clouds
# 37 ambalavao
#  Temperature (in kelvin unit) = 285.5
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 100
#  description = broken clouds
# 38 alekseyevsk
#  Temperature (in kelvin unit) = 285.82
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 74
#  description = scattered clouds
# 39 mataura
#  Temperature (in kelvin unit) = 279.86
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 74
#  description = overcast clouds
# 40 cabo san lucas
#  Temperature (in kelvin unit) = 300.51
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 82
#  description = overcast clouds
# 41 victoria
#  Temperature (in kelvin unit) = 300.77
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 77
#  description = light rain
# 42 bubaque
#  Temperature (in kelvin unit) = 301.46
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 77
#  description = light rain
# 43 barrow
#  Temperature (in kelvin unit) = 272.87
#  atmospheric pressure (in hPa unit) = 993
#  humidity (in percentage) = 98
#  description = light snow
# 44 atuona
#  Temperature (in kelvin unit) = 299.63
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 74
#  description = scattered clouds
# 45 port elizabeth
#  Temperature (in kelvin unit) = 269.84
#  atmospheric pressure (in hPa unit) = 952
#  humidity (in percentage) = 98
#  description = snow
# 46 alofi
#  Temperature (in kelvin unit) = 298.01
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 72
#  description = few clouds
# 47 voskresenskoye
#  Temperature (in kelvin unit) = 287.81
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 85
#  description = overcast clouds
# 48 morag
#  Temperature (in kelvin unit) = 289.82
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 78
#  description = broken clouds
# 49 burica
#  Temperature (in kelvin unit) = 299.85
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 86
#  description = light rain
# 50 grindavik
#  Temperature (in kelvin unit) = 284.15
#  atmospheric pressure (in hPa unit) = 998
#  humidity (in percentage) = 76
#  description = broken clouds
# 51 thompson
#  Temperature (in kelvin unit) = 290.15
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 59
#  description = clear sky
# 52 castro
#  Temperature (in kelvin unit) = 278.77
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 74
#  description = overcast clouds
# 53 sur
#  Temperature (in kelvin unit) = 301.2
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 78
#  description = broken clouds
# 54 tuktoyaktuk
#  Temperature (in kelvin unit) = 280.2
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 86
#  description = overcast clouds
# 55 brokopondo
#  Temperature (in kelvin unit) = 301.51
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 90
#  description = moderate rain
# 56 severo-kurilsk
#  Temperature (in kelvin unit) = 279.86
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 86
#  description = overcast clouds
# 57 isangel
#  Temperature (in kelvin unit) = 296.41
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 80
#  description = few clouds
# 58 lebu
#  Temperature (in kelvin unit) = 287.82
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 66
#  description = broken clouds
# 59 jinchang
#  Temperature (in kelvin unit) = 297.55
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 17
#  description = broken clouds
# 60 abu ghosh
#  Temperature (in kelvin unit) = 295.36
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 78
#  description = clear sky
# 61 haines junction
#  Temperature (in kelvin unit) = 284.72
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 43
#  description = overcast clouds
# 62 huescar
#  Temperature (in kelvin unit) = 300.71
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 34
#  description = clear sky
# 63 ilo
#  Temperature (in kelvin unit) = 290.05
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 76
#  description = overcast clouds
# 64 goundam
#  Temperature (in kelvin unit) = 314.4
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 16
#  description = scattered clouds
# 65 coquimbo
#  Temperature (in kelvin unit) = 289.97
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 76
#  description = broken clouds
# 66 saint-philippe
#  Temperature (in kelvin unit) = 294.17
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 79
#  description = clear sky
# 67 lolua
#  Temperature (in kelvin unit) = 301.95
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 69
#  description = broken clouds
# 68 jamestown
#  Temperature (in kelvin unit) = 294.39
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 58
#  description = scattered clouds
# 69 hermanus
#  Temperature (in kelvin unit) = 228.33
#  atmospheric pressure (in hPa unit) = 1029
#  humidity (in percentage) = 49
#  description = clear sky
# 70 chokurdakh
#  Temperature (in kelvin unit) = 273.77
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 94
#  description = overcast clouds
# 71 san andres
#  Temperature (in kelvin unit) = 301.47
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 81
#  description = few clouds
# 72 bredasdorp
#  Temperature (in kelvin unit) = 224.51
#  atmospheric pressure (in hPa unit) = 1042
#  humidity (in percentage) = 50
#  description = overcast clouds
# 73 san patricio
#  Temperature (in kelvin unit) = 301.6
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 78
#  description = overcast clouds
# 74 ribeira grande
#  Temperature (in kelvin unit) = 296.79
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 76
#  description = clear sky
# 75 manokwari
#  Temperature (in kelvin unit) = 302.87
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 66
#  description = overcast clouds
# 76 dikson
#  Temperature (in kelvin unit) = 274.54
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 88
#  description = few clouds
# 77 punta arenas
#  Temperature (in kelvin unit) = 236.51
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 81
#  description = broken clouds
# 78 provideniya
#  Temperature (in kelvin unit) = 280.62
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 87
#  description = clear sky
# 79 lincoln
#  Temperature (in kelvin unit) = 281.83
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 84
#  description = scattered clouds
# 80 airai
#  Temperature (in kelvin unit) = 302.25
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 77
#  description = overcast clouds
# 81 hami
#  Temperature (in kelvin unit) = 293.24
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 20
#  description = broken clouds
# 82 saldanha
#  Temperature (in kelvin unit) = 288.89
#  atmospheric pressure (in hPa unit) = 999
#  humidity (in percentage) = 89
#  description = light rain
# 83 bam
#  Temperature (in kelvin unit) = 307.87
#  atmospheric pressure (in hPa unit) = 1002
#  humidity (in percentage) = 10
#  description = clear sky
# 84 kuche
#  Temperature (in kelvin unit) = 287.94
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 47
#  description = overcast clouds
# 85 dunedin
#  Temperature (in kelvin unit) = 278.55
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 75
#  description = overcast clouds
# 86 balikpapan
#  Temperature (in kelvin unit) = 294.62
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 94
#  description = broken clouds
# 87 georgetown
#  Temperature (in kelvin unit) = 299.48
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 77
#  description = clear sky
# 88 taonan
#  Temperature (in kelvin unit) = 289.04
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 86
#  description = overcast clouds
# 89 bekeshevskaya
#  Temperature (in kelvin unit) = 297.6
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 57
#  description = few clouds
# 90 cidreira
#  Temperature (in kelvin unit) = 271.77
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 94
#  description = overcast clouds
# 91 norman wells
#  Temperature (in kelvin unit) = 283.51
#  atmospheric pressure (in hPa unit) = 996
#  humidity (in percentage) = 93
#  description = light rain
# 92 nanortalik
#  Temperature (in kelvin unit) = 280.48
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 80
#  description = overcast clouds
# 93 olafsvik
#  Temperature (in kelvin unit) = 282.77
#  atmospheric pressure (in hPa unit) = 997
#  humidity (in percentage) = 82
#  description = broken clouds
# 94 el progreso
#  Temperature (in kelvin unit) = 303.65
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 74
#  description = broken clouds
# 95 rehoboth
#  Temperature (in kelvin unit) = 287.82
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 31
#  description = clear sky
# 96 puerto narino
#  Temperature (in kelvin unit) = 299.97
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 91
#  description = moderate rain
# 97 abha
#  Temperature (in kelvin unit) = 299.9
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 12
#  description = overcast clouds
# 98 arraial do cabo
#  Temperature (in kelvin unit) = 296.11
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 74
#  description = overcast clouds
# 99 ermelo
#  Temperature (in kelvin unit) = 280.34
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 64
#  description = clear sky
# 100 luganville
#  Temperature (in kelvin unit) = 299.6
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 86
#  description = light rain
# 101 cape town
#  Temperature (in kelvin unit) = 247.89
#  atmospheric pressure (in hPa unit) = 993
#  humidity (in percentage) = 88
#  description = clear sky
# 102 mumford
#  Temperature (in kelvin unit) = 296.4
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 77
#  description = overcast clouds
# 103 khatanga
#  Temperature (in kelvin unit) = 273.82
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 95
#  description = clear sky
# 104 kapaa
#  Temperature (in kelvin unit) = 293.12
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 91
#  description = broken clouds
# 105 plettenberg bay
#  Temperature (in kelvin unit) = 287.44
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 81
#  description = light rain
# 106 windsor
#  Temperature (in kelvin unit) = 298.25
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 44
#  description = few clouds
# 107 hithadhoo
#  Temperature (in kelvin unit) = 301.8
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 78
#  description = overcast clouds
# 108 verkhnevilyuysk
#  Temperature (in kelvin unit) = 287.76
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 79
#  description = overcast clouds
# 109 kalabo
#  Temperature (in kelvin unit) = 289.96
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 31
#  description = clear sky
# 110 lagoa
#  Temperature (in kelvin unit) = 287.17
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 78
#  description = overcast clouds
# 111 manoel urbano
#  Temperature (in kelvin unit) = 305.11
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 48
#  description = scattered clouds
# 112 kattivakkam
#  Temperature (in kelvin unit) = 302.55
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 81
#  description = broken clouds
# 113 talnakh
#  Temperature (in kelvin unit) = 273.09
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 100
#  description = overcast clouds
# 114 iquique
#  Temperature (in kelvin unit) = 289.66
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 69
#  description = scattered clouds
# 115 wanning
#  Temperature (in kelvin unit) = 302.91
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 83
#  description = overcast clouds
# 116 tahta
#  Temperature (in kelvin unit) = 306.97
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 14
#  description = clear sky
# 117 mahebourg
#  Temperature (in kelvin unit) = 278.07
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 68
#  description = few clouds
# 118 micomeseng
#  Temperature (in kelvin unit) = 295.41
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 96
#  description = moderate rain
# 119 torbay
#  Temperature (in kelvin unit) = 295.12
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 88
#  description = overcast clouds
# 120 khani
#  Temperature (in kelvin unit) = 284.13
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 83
#  description = broken clouds
# 121 qaanaaq
#  Temperature (in kelvin unit) = 277.61
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 72
#  description = clear sky
# 122 jaipur hat
#  Temperature (in kelvin unit) = 302.53
#  atmospheric pressure (in hPa unit) = 1004
#  humidity (in percentage) = 78
#  description = broken clouds
# 123 hasaki
#  Temperature (in kelvin unit) = 298.01
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 92
#  description = clear sky
# 124 djambala
#  Temperature (in kelvin unit) = 298.26
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 51
#  description = broken clouds
# 125 lannion
#  Temperature (in kelvin unit) = 296.16
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 50
#  description = overcast clouds
# 126 atambua
#  Temperature (in kelvin unit) = 299.92
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 80
#  description = few clouds
# 127 lecce
#  Temperature (in kelvin unit) = 297.15
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 64
#  description = few clouds
# 128 butaritari
#  Temperature (in kelvin unit) = 301.07
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 77
#  description = clear sky
# 129 fort nelson
#  Temperature (in kelvin unit) = 287.84
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 39
#  description = broken clouds
# 130 sola
#  Temperature (in kelvin unit) = 300.48
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 82
#  description = scattered clouds
# 131 magaria
#  Temperature (in kelvin unit) = 310.49
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 21
#  description = scattered clouds
# 132 longyearbyen
#  Temperature (in kelvin unit) = 276.78
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 90
#  description = overcast clouds
# 133 uruzgan
#  Temperature (in kelvin unit) = 291.41
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 25
#  description = clear sky
# 134 mys shmidta
#  Temperature (in kelvin unit) = 272.96
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 98
#  description = overcast clouds
# 135 avarua
#  Temperature (in kelvin unit) = 294.84
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 81
#  description = overcast clouds
# 136 henties bay
#  Temperature (in kelvin unit) = 290.51
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 84
#  description = few clouds
# 137 surt
#  Temperature (in kelvin unit) = 295.98
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 73
#  description = clear sky
# 138 ilulissat
#  Temperature (in kelvin unit) = 267.26
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 96
#  description = few clouds
# 139 of
#  Temperature (in kelvin unit) = 297.15
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 83
#  description = broken clouds
# 140 makakilo city
#  Temperature (in kelvin unit) = 299.3
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 82
#  description = clear sky
# 141 ahipara
#  Temperature (in kelvin unit) = 289.78
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 83
#  description = light rain
# 142 hilo
#  Temperature (in kelvin unit) = 299.1
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 85
#  description = broken clouds
# 143 codrington
#  Temperature (in kelvin unit) = 297.99
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 76
#  description = clear sky
# 144 attawapiskat
#  Temperature (in kelvin unit) = 276.12
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 79
#  description = few clouds
# 145 asayita
#  Temperature (in kelvin unit) = 309.52
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 13
#  description = clear sky
# 146 geraldton
#  Temperature (in kelvin unit) = 291.73
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 31
#  description = clear sky
# 147 east london
#  Temperature (in kelvin unit) = 276.44
#  atmospheric pressure (in hPa unit) = 980
#  humidity (in percentage) = 79
#  description = overcast clouds
# 148 sakaiminato
#  Temperature (in kelvin unit) = 294.08
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 84
#  description = broken clouds
# 149 te anau
#  Temperature (in kelvin unit) = 286.2
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 93
#  description = light rain
# 150 saleaula
#  Temperature (in kelvin unit) = 300.4
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 74
#  description = scattered clouds
# 151 pedernales
#  Temperature (in kelvin unit) = 301.17
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 83
#  description = clear sky
# 152 dauphin
#  Temperature (in kelvin unit) = 297.15
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 38
#  description = overcast clouds
# 153 tiksi
#  Temperature (in kelvin unit) = 273.87
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 93
#  description = scattered clouds
# 154 presidencia roque saenz pena
#  Temperature (in kelvin unit) = 305.37
#  atmospheric pressure (in hPa unit) = 999
#  humidity (in percentage) = 41
#  description = clear sky
# 155 bambous virieux
#  Temperature (in kelvin unit) = 293.17
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 73
#  description = clear sky
# 156 rundu
#  Temperature (in kelvin unit) = 294.15
#  atmospheric pressure (in hPa unit) = 1024
#  humidity (in percentage) = 30
#  description = clear sky
# 157 tripoli
#  Temperature (in kelvin unit) = 295.94
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 77
#  description = clear sky
# 158 huarmey
#  Temperature (in kelvin unit) = 290.63
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 82
#  description = overcast clouds
# 159 rosa zarate
#  Temperature (in kelvin unit) = 300.26
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 74
#  description = broken clouds
# 160 atar
#  Temperature (in kelvin unit) = 318.08
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 6
#  description = clear sky
# 161 haibowan
#  Temperature (in kelvin unit) = 297.43
#  atmospheric pressure (in hPa unit) = 999
#  humidity (in percentage) = 18
#  description = broken clouds
# 162 zhigansk
#  Temperature (in kelvin unit) = 293.87
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 59
#  description = scattered clouds
# 163 kerema
#  Temperature (in kelvin unit) = 296.12
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 90
#  description = broken clouds
# 164 veraval
#  Temperature (in kelvin unit) = 302.01
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 81
#  description = overcast clouds
# 165 broadstairs
#  Temperature (in kelvin unit) = 292.69
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 73
#  description = clear sky
# 166 clyde river
#  Temperature (in kelvin unit) = 273.07
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 99
#  description = overcast clouds
# 167 alenquer
#  Temperature (in kelvin unit) = 300.69
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 78
#  description = light rain
# 168 zhangjiakou
#  Temperature (in kelvin unit) = 291.37
#  atmospheric pressure (in hPa unit) = 1004
#  humidity (in percentage) = 62
#  description = clear sky
# 169 faanui
#  Temperature (in kelvin unit) = 299.64
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 75
#  description = broken clouds
# 170 flin flon
#  Temperature (in kelvin unit) = 292.57
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 37
#  description = clear sky
# 171 husavik
#  Temperature (in kelvin unit) = 275.17
#  atmospheric pressure (in hPa unit) = 1004
#  humidity (in percentage) = 95
#  description = overcast clouds
# 172 ayan
#  Temperature (in kelvin unit) = 279.91
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 91
#  description = broken clouds
# 173 bintulu
#  Temperature (in kelvin unit) = 301.83
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 69
#  description = light rain
# 174 portel
#  Temperature (in kelvin unit) = 306.72
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 42
#  description = scattered clouds
# 175 vila franca do campo
#  Temperature (in kelvin unit) = 289.16
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 86
#  description = light rain
# 176 lasa
#  Temperature (in kelvin unit) = 273.95
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 83
#  description = few clouds
# 177 gimli
#  Temperature (in kelvin unit) = 294.19
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 60
#  description = light rain
# 178 hambantota
#  Temperature (in kelvin unit) = 301.27
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 79
#  description = broken clouds
# 179 grand river south east
#  Temperature (in kelvin unit) = 295.37
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 74
#  description = few clouds
# 180 amderma
#  Temperature (in kelvin unit) = 274.14
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 97
#  description = light rain
# 181 uch
#  Temperature (in kelvin unit) = 313.79
#  atmospheric pressure (in hPa unit) = 998
#  humidity (in percentage) = 14
#  description = clear sky
# 182 chutung
#  Temperature (in kelvin unit) = 301.77
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 75
#  description = overcast clouds
# 183 zhuanghe
#  Temperature (in kelvin unit) = 292.64
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 92
#  description = heavy intensity rain
# 184 kenscoff
#  Temperature (in kelvin unit) = 309.15
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 37
#  description = mist
# 185 barroualie
#  Temperature (in kelvin unit) = 301.17
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 75
#  description = few clouds
# 186 vilcun
#  Temperature (in kelvin unit) = 280.15
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 93
#  description = overcast clouds
# 187 agaro
#  Temperature (in kelvin unit) = 288.05
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 95
#  description = light rain
# 188 kenai
#  Temperature (in kelvin unit) = 282.87
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 93
#  description = overcast clouds
# 189 lubango
#  Temperature (in kelvin unit) = 287.65
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 41
#  description = scattered clouds
# 190 jumla
#  Temperature (in kelvin unit) = 286.3
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 39
#  description = broken clouds
# 191 naze
#  Temperature (in kelvin unit) = 300.23
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 77
#  description = overcast clouds
# 192 asau
#  Temperature (in kelvin unit) = 299.1
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 82
#  description = overcast clouds
# 193 roura
#  Temperature (in kelvin unit) = 300.73
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 75
#  description = light rain
# 194 broken hill
#  Temperature (in kelvin unit) = 280.83
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 62
#  description = clear sky
# 195 stranda
#  Temperature (in kelvin unit) = 288.69
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 78
#  description = light rain
# 196 ambagarh chauki
#  Temperature (in kelvin unit) = 299.08
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 76
#  description = scattered clouds
# 197 banepa
#  Temperature (in kelvin unit) = 276.75
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 85
#  description = broken clouds
# 198 port blair
#  Temperature (in kelvin unit) = 300.62
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 78
#  description = light rain
# 199 kasungu
#  Temperature (in kelvin unit) = 288.63
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 73
#  description = clear sky
# 200 ojinaga
#  Temperature (in kelvin unit) = 306.48
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 41
#  description = overcast clouds
# 201 pochutla
#  Temperature (in kelvin unit) = 302.29
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 76
#  description = light rain
# 202 shenjiamen
#  Temperature (in kelvin unit) = 298.09
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 92
#  description = light rain
# 203 samusu
#  Temperature (in kelvin unit) = 301.76
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 72
#  description = light rain
# 204 aklavik
#  Temperature (in kelvin unit) = 272.97
#  atmospheric pressure (in hPa unit) = 1002
#  humidity (in percentage) = 97
#  description = few clouds
# 205 ewa beach
#  Temperature (in kelvin unit) = 298.08
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 77
#  description = broken clouds
# 206 nuevo progreso
#  Temperature (in kelvin unit) = 301.99
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 84
#  description = scattered clouds
# 207 upernavik
#  Temperature (in kelvin unit) = 272.04
#  atmospheric pressure (in hPa unit) = 1002
#  humidity (in percentage) = 94
#  description = overcast clouds
# 208 kruisfontein
#  Temperature (in kelvin unit) = 268.35
#  atmospheric pressure (in hPa unit) = 957
#  humidity (in percentage) = 95
#  description = light snow
# 209 panama city
#  Temperature (in kelvin unit) = 301.39
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 77
#  description = light rain
# 210 shakawe
#  Temperature (in kelvin unit) = 288.62
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 34
#  description = clear sky
# 211 iqaluit
#  Temperature (in kelvin unit) = 274.32
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 92
#  description = broken clouds
# 212 avera
#  Temperature (in kelvin unit) = 294.95
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 62
#  description = broken clouds
# 213 pevek
#  Temperature (in kelvin unit) = 273.14
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 98
#  description = overcast clouds
# 214 luderitz
#  Temperature (in kelvin unit) = 286.61
#  atmospheric pressure (in hPa unit) = 999
#  humidity (in percentage) = 75
#  description = broken clouds
# 215 ituni
#  Temperature (in kelvin unit) = 297.71
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 93
#  description = moderate rain
# 216 mopti
#  Temperature (in kelvin unit) = 307.26
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 28
#  description = light rain
# 217 fuyu
#  Temperature (in kelvin unit) = 288.2
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 94
#  description = broken clouds
# 218 yeppoon
#  Temperature (in kelvin unit) = 294.43
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 57
#  description = few clouds
# 219 salem
#  Temperature (in kelvin unit) = 300.24
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 58
#  description = broken clouds
# 220 mehran
#  Temperature (in kelvin unit) = 308.59
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 10
#  description = clear sky
# 221 nizhneyansk
#  Temperature (in kelvin unit) = 274.17
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 92
#  description = overcast clouds
# 222 nguiu
#  Temperature (in kelvin unit) = 299.86
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 79
#  description = scattered clouds
# 223 taburi
#  Temperature (in kelvin unit) = 303.01
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 70
#  description = broken clouds
# 224 dakar
#  Temperature (in kelvin unit) = 299.28
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 81
#  description = few clouds
# 225 swan river
#  Temperature (in kelvin unit) = 294.64
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 40
#  description = clear sky
# 226 marzuq
#  Temperature (in kelvin unit) = 305.88
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 14
#  description = clear sky
# 227 guerrero negro
#  Temperature (in kelvin unit) = 293.66
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 89
#  description = scattered clouds
# 228 muncar
#  Temperature (in kelvin unit) = 300.29
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 76
#  description = overcast clouds
# 229 belushya guba
#  Temperature (in kelvin unit) = 273.98
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 93
#  description = overcast clouds
# 230 tual
#  Temperature (in kelvin unit) = 300.32
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 81
#  description = few clouds
# 231 ladario
#  Temperature (in kelvin unit) = 306.15
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 41
#  description = few clouds
# 232 mackay
#  Temperature (in kelvin unit) = 295.94
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 73
#  description = scattered clouds
# 233 pisco
#  Temperature (in kelvin unit) = 291.99
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 75
#  description = overcast clouds
# 234 slave lake
#  Temperature (in kelvin unit) = 284.18
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 97
#  description = overcast clouds
# 235 sorvag
#  Temperature (in kelvin unit) = 283.77
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 87
#  description = broken clouds
# 236 clinton
#  Temperature (in kelvin unit) = 296.64
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 46
#  description = broken clouds
# 237 chunskiy
#  Temperature (in kelvin unit) = 288.22
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 83
#  description = overcast clouds
# 238 moses lake
#  Temperature (in kelvin unit) = 300.15
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 34
#  description = clear sky
# 239 warqla
#  Temperature (in kelvin unit) = 309.24
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 10
#  description = clear sky
# 240 sorland
#  Temperature (in kelvin unit) = 285.15
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 92
#  description = overcast clouds
# 241 axim
#  Temperature (in kelvin unit) = 296.54
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 80
#  description = scattered clouds
# 242 portland
#  Temperature (in kelvin unit) = 278.98
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 91
#  description = overcast clouds
# 243 sao lourenco do sul
#  Temperature (in kelvin unit) = 297.5
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 74
#  description = scattered clouds
# 244 bayji
#  Temperature (in kelvin unit) = 307.61
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 11
#  description = clear sky
# 245 medak
#  Temperature (in kelvin unit) = 301.48
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 51
#  description = scattered clouds
# 246 cockburn town
#  Temperature (in kelvin unit) = 300.25
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 78
#  description = broken clouds
# 247 omboue
#  Temperature (in kelvin unit) = 296.07
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 80
#  description = overcast clouds
# 248 souillac
#  Temperature (in kelvin unit) = 277.19
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 76
#  description = overcast clouds
# 249 vanimo
#  Temperature (in kelvin unit) = 302.82
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 71
#  description = light rain
# 250 cherskiy
#  Temperature (in kelvin unit) = 273.61
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 97
#  description = overcast clouds
# 251 barentsburg
#  Temperature (in kelvin unit) = 275.38
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 95
#  description = overcast clouds
# 252 nhulunbuy
#  Temperature (in kelvin unit) = 299.05
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 68
#  description = clear sky
# 253 marsa matruh
#  Temperature (in kelvin unit) = 304.43
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 14
#  description = clear sky
# 254 yulara
#  Temperature (in kelvin unit) = 287.4
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 38
#  description = clear sky
# 255 altay
#  Temperature (in kelvin unit) = 294.41
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 23
#  description = scattered clouds
# 256 palabuhanratu
#  Temperature (in kelvin unit) = 299.07
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 77
#  description = broken clouds
# 257 baykit
#  Temperature (in kelvin unit) = 287.89
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 87
#  description = overcast clouds
# 258 kayerkan
#  Temperature (in kelvin unit) = 286.59
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 63
#  description = scattered clouds
# 259 ishigaki
#  Temperature (in kelvin unit) = 302.38
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 89
#  description = few clouds
# 260 san cristobal
#  Temperature (in kelvin unit) = 294.77
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 81
#  description = clear sky
# 261 gamba
#  Temperature (in kelvin unit) = 296.8
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 73
#  description = broken clouds
# 262 bilma
#  Temperature (in kelvin unit) = 307.93
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 10
#  description = few clouds
# 263 los llanos de aridane
#  Temperature (in kelvin unit) = 295.05
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 78
#  description = overcast clouds
# 264 thinadhoo
#  Temperature (in kelvin unit) = 302.2
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 76
#  description = overcast clouds
# 265 praia
#  Temperature (in kelvin unit) = 300.83
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 77
#  description = scattered clouds
# 266 charters towers
#  Temperature (in kelvin unit) = 284.57
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 61
#  description = clear sky
# 267 iskateley
#  Temperature (in kelvin unit) = 277.04
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 91
#  description = overcast clouds
# 268 pergamino
#  Temperature (in kelvin unit) = 286.14
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 90
#  description = overcast clouds
# 269 tilichiki
#  Temperature (in kelvin unit) = 284.74
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 77
#  description = scattered clouds
# 270 mackenzie
#  Temperature (in kelvin unit) = 283.58
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 49
#  description = few clouds
# 271 lillesand
#  Temperature (in kelvin unit) = 292.34
#  atmospheric pressure (in hPa unit) = 1023
#  humidity (in percentage) = 72
#  description = clear sky
# 272 madang
#  Temperature (in kelvin unit) = 295.73
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 96
#  description = scattered clouds
# 273 rio gallegos
#  Temperature (in kelvin unit) = 280.39
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 86
#  description = light rain
# 274 nishihara
#  Temperature (in kelvin unit) = 301.49
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 72
#  description = overcast clouds
# 275 constitucion
#  Temperature (in kelvin unit) = 296.71
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 83
#  description = broken clouds
# 276 roebourne
#  Temperature (in kelvin unit) = 290.93
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 40
#  description = clear sky
# 277 calvinia
#  Temperature (in kelvin unit) = 289.26
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 30
#  description = clear sky
# 278 bjornevatn
#  Temperature (in kelvin unit) = 291.15
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 31
#  description = scattered clouds
# 279 pavlodolskaya
#  Temperature (in kelvin unit) = 299.15
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 65
#  description = clear sky
# 280 banyo
#  Temperature (in kelvin unit) = 296.73
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 88
#  description = light rain
# 281 oriximina
#  Temperature (in kelvin unit) = 301.82
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 66
#  description = light rain
# 282 safwah
#  Temperature (in kelvin unit) = 301.92
#  atmospheric pressure (in hPa unit) = 1000
#  humidity (in percentage) = 31
#  description = clear sky
# 283 vila do maio
#  Temperature (in kelvin unit) = 298.56
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 74
#  description = clear sky
# 284 sarkikaraagac
#  Temperature (in kelvin unit) = 288.88
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 69
#  description = clear sky
# 285 vidim
#  Temperature (in kelvin unit) = 286.97
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 80
#  description = few clouds
# 286 puerto baquerizo moreno
#  Temperature (in kelvin unit) = 294.56
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 86
#  description = overcast clouds
# 287 natal
#  Temperature (in kelvin unit) = 299.74
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 76
#  description = overcast clouds
# 288 saint-pierre
#  Temperature (in kelvin unit) = 295.98
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 84
#  description = broken clouds
# 289 badaojiang
#  Temperature (in kelvin unit) = 287.63
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 99
#  description = moderate rain
# 290 wilmington
#  Temperature (in kelvin unit) = 305.38
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 43
#  description = broken clouds
# 291 chagda
#  Temperature (in kelvin unit) = 280.78
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 84
#  description = broken clouds
# 292 kodiak
#  Temperature (in kelvin unit) = 282.8
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 87
#  description = light rain
# 293 trinidad
#  Temperature (in kelvin unit) = 301.77
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 83
#  description = scattered clouds
# 294 vernon
#  Temperature (in kelvin unit) = 298.56
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 73
#  description = few clouds
# 295 touros
#  Temperature (in kelvin unit) = 299.63
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 77
#  description = few clouds
# 296 bengkulu
#  Temperature (in kelvin unit) = 300.16
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 80
#  description = light rain
# 297 sinjar
#  Temperature (in kelvin unit) = 303.6
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 13
#  description = clear sky
# 298 tynda
#  Temperature (in kelvin unit) = 280.89
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 90
#  description = clear sky
# 299 hamilton
#  Temperature (in kelvin unit) = 299.5
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 79
#  description = broken clouds
# 300 yatou
#  Temperature (in kelvin unit) = 293.63
#  atmospheric pressure (in hPa unit) = 1002
#  humidity (in percentage) = 91
#  description = heavy intensity rain
# 301 moron
#  Temperature (in kelvin unit) = 281.39
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 80
#  description = overcast clouds
# 302 kyabram
#  Temperature (in kelvin unit) = 282.04
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 96
#  description = clear sky
# 303 vardo
#  Temperature (in kelvin unit) = 274.27
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 90
#  description = clear sky
# 304 cortez
#  Temperature (in kelvin unit) = 303.89
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 13
#  description = clear sky
# 305 san quintin
#  Temperature (in kelvin unit) = 291.68
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 84
#  description = overcast clouds
# 306 port hedland
#  Temperature (in kelvin unit) = 286.96
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 44
#  description = clear sky
# 307 amuntai
#  Temperature (in kelvin unit) = 296.19
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 98
#  description = overcast clouds
# 308 dawson creek
#  Temperature (in kelvin unit) = 284.82
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 76
#  description = light rain
# 309 kaspiyskiy
#  Temperature (in kelvin unit) = 298.57
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 61
#  description = clear sky
# 310 rafai
#  Temperature (in kelvin unit) = 296.98
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 77
#  description = scattered clouds
# 311 aksu
#  Temperature (in kelvin unit) = 302.43
# ...
#  humidity (in percentage) = 95
#  description = overcast clouds
# 495 nago
#  Temperature (in kelvin unit) = 298.84
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 92
#  description = overcast clouds
# 496 nueva loja
#  Temperature (in kelvin unit) = 296.15
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 94
#  description = light rain
# 497 yumen
#  Temperature (in kelvin unit) = 283.08
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 43
#  description = scattered clouds
# 498 biak
#  Temperature (in kelvin unit) = 302.79
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 71
#  description = light rain
# 499 sao gabriel da cachoeira
#  Temperature (in kelvin unit) = 304.15
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 70
#  description = scattered clouds
# 500 liverpool
#  Temperature (in kelvin unit) = 294.26
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 87
#  description = clear sky
# 501 pontevel
#  Temperature (in kelvin unit) = 302.22
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 57
#  description = scattered clouds
# 502 dawlatabad
#  Temperature (in kelvin unit) = 285.65
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 41
#  description = clear sky
# 503 cooma
#  Temperature (in kelvin unit) = 285.93
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 93
#  description = light rain
# 504 hervey bay
#  Temperature (in kelvin unit) = 292.67
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 57
#  description = clear sky
# 505 tonj
#  Temperature (in kelvin unit) = 297.15
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 85
#  description = overcast clouds
# 506 potgietersrus
#  Temperature (in kelvin unit) = 286.44
#  atmospheric pressure (in hPa unit) = 1025
#  humidity (in percentage) = 39
#  description = clear sky
# 507 am timan
#  Temperature (in kelvin unit) = 305.71
#  atmospheric pressure (in hPa unit) = 1006
#  humidity (in percentage) = 33
#  description = scattered clouds
# 508 hastings
#  Temperature (in kelvin unit) = 285.59
#  atmospheric pressure (in hPa unit) = 1024
#  humidity (in percentage) = 67
#  description = broken clouds
# 509 tupik
#  Temperature (in kelvin unit) = 280.81
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 96
#  description = scattered clouds
# 510 santa eulalia del rio
#  Temperature (in kelvin unit) = 299.48
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 56
#  description = clear sky
# 511 bilibino
#  Temperature (in kelvin unit) = 278.09
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 67
#  description = broken clouds
# 512 saint george
#  Temperature (in kelvin unit) = 297.45
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 89
#  description = light rain
# 513 sakakah
#  Temperature (in kelvin unit) = 300.32
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 14
#  description = clear sky
# 514 nortelandia
#  Temperature (in kelvin unit) = 304.8
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 30
#  description = clear sky
# 515 svetlyy
#  Temperature (in kelvin unit) = 286.33
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 54
#  description = clear sky
# 516 gat
#  Temperature (in kelvin unit) = 303.28
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 13
#  description = broken clouds
# 517 nandu
#  Temperature (in kelvin unit) = 296.16
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 100
#  description = overcast clouds
# 518 pyaozerskiy
#  Temperature (in kelvin unit) = 294.15
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 47
#  description = clear sky
# 519 saryshagan
#  Temperature (in kelvin unit) = 295.85
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 39
#  description = broken clouds
# 520 talas
#  Temperature (in kelvin unit) = 281.61
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 54
#  description = broken clouds
# 521 roma
#  Temperature (in kelvin unit) = 275.15
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 74
#  description = clear sky
# 522 lorengau
#  Temperature (in kelvin unit) = 302.93
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 69
#  description = broken clouds
# 523 soyo
#  Temperature (in kelvin unit) = 297.38
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 72
#  description = clear sky
# 524 blagoyevo
#  Temperature (in kelvin unit) = 279.99
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 63
#  description = few clouds
# 525 santo tomas
#  Temperature (in kelvin unit) = 282.63
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 49
#  description = broken clouds
# 526 suyan
#  Temperature (in kelvin unit) = 294.82
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 83
#  description = scattered clouds
# 527 sinnamary
#  Temperature (in kelvin unit) = 298.77
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 73
#  description = few clouds
# 528 lompoc
#  Temperature (in kelvin unit) = 295.17
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 85
#  description = broken clouds
# 529 puri
#  Temperature (in kelvin unit) = 302.2
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 83
#  description = broken clouds
# 530 antofagasta
#  Temperature (in kelvin unit) = 288.63
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 79
#  description = overcast clouds
# 531 skoghall
#  Temperature (in kelvin unit) = 297.69
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 56
#  description = clear sky
# 532 yeletskiy
#  Temperature (in kelvin unit) = 280.98
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 84
#  description = light rain
# 533 seoul
#  Temperature (in kelvin unit) = 296.15
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 69
#  description = overcast clouds
# 534 chipiona
#  Temperature (in kelvin unit) = 304.15
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 38
#  description = clear sky
# 535 panacan
#  Temperature (in kelvin unit) = 302.56
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 66
#  description = clear sky
# 536 heihe
#  Temperature (in kelvin unit) = 285.15
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 100
#  description = light intensity shower rain
# 537 ejura
#  Temperature (in kelvin unit) = 301.53
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 71
#  description = scattered clouds
# 538 marawi
#  Temperature (in kelvin unit) = 307.8
#  atmospheric pressure (in hPa unit) = 1004
#  humidity (in percentage) = 10
#  description = scattered clouds
# 539 novyy urengoy
#  Temperature (in kelvin unit) = 280.9
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 83
#  description = broken clouds
# 540 matara
#  Temperature (in kelvin unit) = 302.15
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 78
#  description = light rain
# 541 kampot
#  Temperature (in kelvin unit) = 302.67
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 68
#  description = scattered clouds
# 542 dingle
#  Temperature (in kelvin unit) = 286.67
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 78
#  description = scattered clouds
# 543 ngukurr
#  Temperature (in kelvin unit) = 286.84
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 36
#  description = clear sky
# 544 oranjemund
#  Temperature (in kelvin unit) = 289.13
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 72
#  description = clear sky
# 545 timaru
#  Temperature (in kelvin unit) = 277.59
#  atmospheric pressure (in hPa unit) = 1025
#  humidity (in percentage) = 97
#  description = clear sky
# 546 tabou
#  Temperature (in kelvin unit) = 298.99
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 78
#  description = scattered clouds
# 547 rocha
#  Temperature (in kelvin unit) = 275.55
#  atmospheric pressure (in hPa unit) = 1005
#  humidity (in percentage) = 95
#  description = scattered clouds
# 548 smithers
#  Temperature (in kelvin unit) = 286.15
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 76
#  description = broken clouds
# 549 saint-georges
#  Temperature (in kelvin unit) = 300.48
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 78
#  description = moderate rain
# 550 adrar
#  Temperature (in kelvin unit) = 313.74
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 7
#  description = clear sky
# 551 magadan
#  Temperature (in kelvin unit) = 279.16
#  atmospheric pressure (in hPa unit) = 1022
#  humidity (in percentage) = 86
#  description = clear sky
# 552 kyren
#  Temperature (in kelvin unit) = 281.28
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 87
#  description = broken clouds
# 553 sistranda
#  Temperature (in kelvin unit) = 285.76
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 89
#  description = overcast clouds
# 554 vostok
#  Temperature (in kelvin unit) = 278.95
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 93
#  description = overcast clouds
# 555 camopi
#  Temperature (in kelvin unit) = 300.77
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 89
#  description = moderate rain
# 556 whyalla
#  Temperature (in kelvin unit) = 279.34
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 90
#  description = clear sky
# 557 sprockhovel
#  Temperature (in kelvin unit) = 300.22
#  atmospheric pressure (in hPa unit) = 1021
#  humidity (in percentage) = 36
#  description = clear sky
# 558 castelnaudary
#  Temperature (in kelvin unit) = 302.76
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 37
#  description = clear sky
# 559 marsh harbour
#  Temperature (in kelvin unit) = 300.71
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 81
#  description = light rain
# 560 umm lajj
#  Temperature (in kelvin unit) = 312.15
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 7
#  description = scattered clouds
# 561 keuruu
#  Temperature (in kelvin unit) = 298.53
#  atmospheric pressure (in hPa unit) = 1020
#  humidity (in percentage) = 36
#  description = few clouds
# 562 skala
#  Temperature (in kelvin unit) = 296.15
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 78
#  description = scattered clouds
# 563 cururupu
#  Temperature (in kelvin unit) = 300.89
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 77
#  description = light rain
# 564 bac lieu
#  Temperature (in kelvin unit) = 302.96
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 69
#  description = overcast clouds
# 565 narsaq
#  Temperature (in kelvin unit) = 270.55
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 94
#  description = clear sky
# 566 jiuquan
#  Temperature (in kelvin unit) = 292.03
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 23
#  description = few clouds
# 567 bowen
#  Temperature (in kelvin unit) = 297.57
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 77
#  description = scattered clouds
# 568 berlevag
#  Temperature (in kelvin unit) = 276.32
#  atmospheric pressure (in hPa unit) = 1024
#  humidity (in percentage) = 84
#  description = scattered clouds
# 569 itupiranga
#  Temperature (in kelvin unit) = 301.15
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 51
#  description = few clouds
# 570 ansalta
#  Temperature (in kelvin unit) = 282.13
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 91
#  description = broken clouds
# 571 acarau
#  Temperature (in kelvin unit) = 300.93
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 78
#  description = scattered clouds
# 572 ajdabiya
#  Temperature (in kelvin unit) = 297.69
#  atmospheric pressure (in hPa unit) = 1015
#  humidity (in percentage) = 49
#  description = clear sky
# 573 omsukchan
#  Temperature (in kelvin unit) = 289.75
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 67
#  description = broken clouds
# 574 yenagoa
#  Temperature (in kelvin unit) = 297.84
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 73
#  description = overcast clouds
# 575 marsabit
#  Temperature (in kelvin unit) = 304.65
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 36
#  description = scattered clouds
# 576 gizo
#  Temperature (in kelvin unit) = 299.6
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 78
#  description = overcast clouds
# 577 le port
#  Temperature (in kelvin unit) = 296.41
#  atmospheric pressure (in hPa unit) = 1019
#  humidity (in percentage) = 76
#  description = clear sky
# 578 bow island
#  Temperature (in kelvin unit) = 299.54
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 45
#  description = broken clouds
# 579 kushiro
#  Temperature (in kelvin unit) = 288.22
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 92
#  description = overcast clouds
# 580 viligili
#  Temperature (in kelvin unit) = 302.3
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 77
#  description = overcast clouds
# 581 sedelnikovo
#  Temperature (in kelvin unit) = 284.28
#  atmospheric pressure (in hPa unit) = 1009
#  humidity (in percentage) = 94
#  description = light rain
# 582 menongue
#  Temperature (in kelvin unit) = 286.92
#  atmospheric pressure (in hPa unit) = 1017
#  humidity (in percentage) = 38
#  description = clear sky
# 583 shitanjing
#  Temperature (in kelvin unit) = 297.04
#  atmospheric pressure (in hPa unit) = 827
#  humidity (in percentage) = 23
#  description = broken clouds
# 584 olga
#  Temperature (in kelvin unit) = 289.44
#  atmospheric pressure (in hPa unit) = 1014
#  humidity (in percentage) = 87
#  description = overcast clouds
# 585 deer lake
#  Temperature (in kelvin unit) = 292.65
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 76
#  description = broken clouds
# 586 san jeronimo de tunan
#  Temperature (in kelvin unit) = 283.03
#  atmospheric pressure (in hPa unit) = 1013
#  humidity (in percentage) = 66
#  description = light rain
# 587 the valley
#  Temperature (in kelvin unit) = 300.65
#  atmospheric pressure (in hPa unit) = 1018
#  humidity (in percentage) = 75
#  description = clear sky
# 588 la primavera
#  Temperature (in kelvin unit) = 302.6
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 75
#  description = light rain
# 589 banjar
#  Temperature (in kelvin unit) = 300.56
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 75
#  description = broken clouds
# 590 lalmohan
#  Temperature (in kelvin unit) = 302.36
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 85
#  description = broken clouds
# 591 siuna
#  Temperature (in kelvin unit) = 300.5
#  atmospheric pressure (in hPa unit) = 1012
#  humidity (in percentage) = 84
#  description = moderate rain
# 592 ottawa
#  Temperature (in kelvin unit) = 302.04
#  atmospheric pressure (in hPa unit) = 1001
#  humidity (in percentage) = 66
#  description = light rain
# 593 goderich
#  Temperature (in kelvin unit) = 299.88
#  atmospheric pressure (in hPa unit) = 1010
#  humidity (in percentage) = 82
#  description = light rain
# 594 tuatapere
#  Temperature (in kelvin unit) = 276.84
#  atmospheric pressure (in hPa unit) = 1026
#  humidity (in percentage) = 79
#  description = overcast clouds
# 595 fairbanks
#  Temperature (in kelvin unit) = 273.1
#  atmospheric pressure (in hPa unit) = 1007
#  humidity (in percentage) = 96
#  description = overcast clouds
# 596 puerto del rosario
#  Temperature (in kelvin unit) = 307.79
#  atmospheric pressure (in hPa unit) = 1011
#  humidity (in percentage) = 19
#  description = clear sky
# 597 thai binh
#  Temperature (in kelvin unit) = 303.01
#  atmospheric pressure (in hPa unit) = 1003
#  humidity (in percentage) = 83
#  description = overcast clouds

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.DataFrame()
df['cities']= citylistclean
df['lat']= latlistclean
df['lon']=  lonlistclean
df['temperature']= temp_list
df['humidity']= humidity_list
df['pressure']= pressure_list
df['wind']= wind_list
df['cloud']= cloud_list

df
# Out:
#                  cities        lat         lon  temperature  humidity  \
# 0      illoqqortoormiut  89.173604  -18.174980       274.27        91
# 1               ushuaia -67.457741  -44.099450       248.80        90
# 2                 bayir  29.964553   37.136680       297.04        18
# 3                 bluff -69.417873  162.281595       245.76        79
# 4             taolanaro -79.946784   67.733797       219.66        39
# ..                  ...        ...         ...          ...       ...
# 593            goderich   5.075310  -18.444618       299.88        82
# 594           tuatapere -53.815552  157.900950       276.84        79
# 595           fairbanks  71.036065 -143.148219       273.10        96
# 596  puerto del rosario  26.076271  -11.673208       307.79        19
# 597           thai binh  19.231308  107.619206       303.01        83
#
#      pressure   wind  cloud
# 0        1014   3.98     68
# 1        1006   4.37     48
# 2        1012   5.25      0
# 3         982   4.91      0
# 4        1058   3.70     96
# ..        ...    ...    ...
# 593      1010   7.37     74
# 594      1026  10.09     98
# 595      1007   1.09    100
# 596      1011   8.04      0
# 597      1003  11.78     97
#
# [598 rows x 8 columns]

# %%
df.to_csv('weatherdf.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

df[df['humidity'].gt(99)].index[0]
# Out:
# 37

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
